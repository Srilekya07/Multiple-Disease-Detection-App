# %% [markdown]
# ## PNEUOMIA DETECTION IN LUNGS USING CNN

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
import cv2
from keras.preprocessing.image import img_to_array

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)

# %%
train_images = r"C:\Users\pnuka\Desktop\LUNGS DEMO\chest_xray\train"

# %%
train_generator = train_datagen.flow_from_directory(train_images,
    target_size = (300,300),
    batch_size = 128,
    class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
validation_generator = test_datagen.flow_from_directory(r"C:\Users\pnuka\Desktop\LUNGS DEMO\chest_xray\train",
    target_size= (300,300),
    batch_size = 128,
    class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.

# %% [markdown]
# ## pneumonia

# %%
plot_image = plt.figure(figsize=(10,10))

plot1 = plot_image.add_subplot(3,2,1)
plot2 = plot_image.add_subplot(3,2,2)
plot3 = plot_image.add_subplot(3,2,3)
plot4 = plot_image.add_subplot(3,2,4)
plot5 = plot_image.add_subplot(3,2,5)
plot6 = plot_image.add_subplot(3,2,6)
plot1.matshow(plt.imread(train_generator.filepaths[41]))
plot2.matshow(plt.imread(train_generator.filepaths[176]))
plot3.matshow(plt.imread(train_generator.filepaths[1553]))
plot4.matshow(plt.imread(train_generator.filepaths[354]))
plot5.matshow(plt.imread(train_generator.filepaths[2679]))
plot6.matshow(plt.imread(train_generator.filepaths[2710]))

# %% [markdown]
# ## normal

# %%
plot_image = plt.figure(figsize=(10,10))

plot1 = plot_image.add_subplot(3,2,1)
plot2 = plot_image.add_subplot(3,2,2)
plot3 = plot_image.add_subplot(3,2,3)
plot4 = plot_image.add_subplot(3,2,4)
plot5 = plot_image.add_subplot(3,2,5)
plot6 = plot_image.add_subplot(3,2,6)
plot1.matshow(plt.imread(train_generator.filepaths[1419]))
plot2.matshow(plt.imread(train_generator.filepaths[1365]))
plot3.matshow(plt.imread(train_generator.filepaths[1400]))
plot4.matshow(plt.imread(train_generator.filepaths[1350]))
plot5.matshow(plt.imread(train_generator.filepaths[1345]))
plot6.matshow(plt.imread(train_generator.filepaths[1349]))

# %% [markdown]
# ## Neural networks using tensor flow

# %%
model= tf.keras.models.Sequential([
                                   tf.keras.layers.Conv2D(16, (3,3), activation= 'relu', input_shape= (300, 300, 3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(32, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(64, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),

                                   tf.keras.layers.Flatten(),
                                   tf.keras.layers.Dense(256, activation= 'relu'),
                                   tf.keras.layers.Dense(512, activation= 'relu'),
                                   tf.keras.layers.Dense(1, activation= 'sigmoid')
])
model.summary()
model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])
# Out:
# C:\Users\pnuka\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 298, 298, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 149, 149, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 147, 147, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 73, 73, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 71, 71, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 35, 35, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 33, 33, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       1,605,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,983,009 (7.56 MB)
#  Trainable params: 1,983,009 (7.56 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model

# %%
history = model.fit(train_generator, epochs = 50, validation_data = validation_generator)
# Out:
# C:\Users\pnuka\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 558s 13s/step - accuracy: 0.7485 - loss: 0.6541 - val_accuracy: 0.7429 - val_loss: 0.5881
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 556s 14s/step - accuracy: 0.8130 - loss: 0.4185 - val_accuracy: 0.9043 - val_loss: 0.2334
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 531s 13s/step - accuracy: 0.8860 - loss: 0.2667 - val_accuracy: 0.9304 - val_loss: 0.1736
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 525s 13s/step - accuracy: 0.9132 - loss: 0.2174 - val_accuracy: 0.9482 - val_loss: 0.1387
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 543s 13s/step - accuracy: 0.9144 - loss: 0.1976 - val_accuracy: 0.9216 - val_loss: 0.1963
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 512s 13s/step - accuracy: 0.9247 - loss: 0.1898 - val_accuracy: 0.9546 - val_loss: 0.1164
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 531s 13s/step - accuracy: 0.9264 - loss: 0.1806 - val_accuracy: 0.9438 - val_loss: 0.1498
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 524s 13s/step - accuracy: 0.9324 - loss: 0.1665 - val_accuracy: 0.9406 - val_loss: 0.1559
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 295s 7s/step - accuracy: 0.9450 - loss: 0.1374 - val_accuracy: 0.9465 - val_loss: 0.1338
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 284s 7s/step - accuracy: 0.9537 - loss: 0.1206 - val_accuracy: 0.9507 - val_loss: 0.1373
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 305s 7s/step - accuracy: 0.9437 - loss: 0.1385 - val_accuracy: 0.9653 - val_loss: 0.0944
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 282s 7s/step - accuracy: 0.9491 - loss: 0.1379 - val_accuracy: 0.9620 - val_loss: 0.0983
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 282s 7s/step - accuracy: 0.9579 - loss: 0.1148 - val_accuracy: 0.9651 - val_loss: 0.0958
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 285s 7s/step - accuracy: 0.9526 - loss: 0.1128 - val_accuracy: 0.9597 - val_loss: 0.1016
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 290s 7s/step - accuracy: 0.9568 - loss: 0.1118 - val_accuracy: 0.9607 - val_loss: 0.1005
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 283s 7s/step - accuracy: 0.9624 - loss: 0.0986 - val_accuracy: 0.9674 - val_loss: 0.0856
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 290s 7s/step - accuracy: 0.9665 - loss: 0.0945 - val_accuracy: 0.9684 - val_loss: 0.0874
# Epoch 18/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 284s 7s/step - accuracy: 0.9606 - loss: 0.0940 - val_accuracy: 0.9557 - val_loss: 0.1133
# Epoch 19/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 281s 7s/step - accuracy: 0.9637 - loss: 0.0955 - val_accuracy: 0.9691 - val_loss: 0.0822
# Epoch 20/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 280s 7s/step - accuracy: 0.9667 - loss: 0.0954 - val_accuracy: 0.9601 - val_loss: 0.1061
# Epoch 21/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 286s 7s/step - accuracy: 0.9544 - loss: 0.1177 - val_accuracy: 0.9595 - val_loss: 0.1070
# Epoch 22/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 284s 7s/step - accuracy: 0.9679 - loss: 0.0914 - val_accuracy: 0.9757 - val_loss: 0.0666
# Epoch 23/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 301s 7s/step - accuracy: 0.9672 - loss: 0.0834 - val_accuracy: 0.9607 - val_loss: 0.1044
# Epoch 24/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 312s 8s/step - accuracy: 0.9693 - loss: 0.0875 - val_accuracy: 0.9663 - val_loss: 0.0837
# Epoch 25/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 286s 7s/step - accuracy: 0.9689 - loss: 0.0744 - val_accuracy: 0.9655 - val_loss: 0.0851
# Epoch 26/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 282s 7s/step - accuracy: 0.9686 - loss: 0.0786 - val_accuracy: 0.9641 - val_loss: 0.0844
# Epoch 27/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 351s 9s/step - accuracy: 0.9678 - loss: 0.0956 - val_accuracy: 0.9638 - val_loss: 0.0934
# Epoch 28/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 512s 13s/step - accuracy: 0.9764 - loss: 0.0723 - val_accuracy: 0.9774 - val_loss: 0.0561
# Epoch 29/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 518s 13s/step - accuracy: 0.9801 - loss: 0.0610 - val_accuracy: 0.9812 - val_loss: 0.0493
# Epoch 30/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 501s 12s/step - accuracy: 0.9736 - loss: 0.0679 - val_accuracy: 0.9699 - val_loss: 0.0733
# Epoch 31/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 287s 7s/step - accuracy: 0.9769 - loss: 0.0598 - val_accuracy: 0.9837 - val_loss: 0.0428
# Epoch 32/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2335s 57s/step - accuracy: 0.9688 - loss: 0.0923 - val_accuracy: 0.9728 - val_loss: 0.0712
# Epoch 33/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 294s 7s/step - accuracy: 0.9724 - loss: 0.0706 - val_accuracy: 0.9572 - val_loss: 0.1042
# Epoch 34/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 289s 7s/step - accuracy: 0.9637 - loss: 0.0871 - val_accuracy: 0.9803 - val_loss: 0.0487
# Epoch 35/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 342s 8s/step - accuracy: 0.9737 - loss: 0.0675 - val_accuracy: 0.9803 - val_loss: 0.0520
# Epoch 36/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 320s 8s/step - accuracy: 0.9767 - loss: 0.0604 - val_accuracy: 0.9630 - val_loss: 0.0971
# Epoch 37/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 320s 8s/step - accuracy: 0.9730 - loss: 0.0798 - val_accuracy: 0.9816 - val_loss: 0.0469
# Epoch 38/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 300s 7s/step - accuracy: 0.9798 - loss: 0.0546 - val_accuracy: 0.9797 - val_loss: 0.0477
# Epoch 39/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 289s 7s/step - accuracy: 0.9798 - loss: 0.0579 - val_accuracy: 0.9872 - val_loss: 0.0345
# Epoch 40/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 301s 7s/step - accuracy: 0.9719 - loss: 0.0771 - val_accuracy: 0.9762 - val_loss: 0.0624
# Epoch 41/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 301s 7s/step - accuracy: 0.9790 - loss: 0.0600 - val_accuracy: 0.9714 - val_loss: 0.0720
# Epoch 42/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 302s 7s/step - accuracy: 0.9708 - loss: 0.0811 - val_accuracy: 0.9716 - val_loss: 0.0698
# Epoch 43/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 285s 7s/step - accuracy: 0.9821 - loss: 0.0518 - val_accuracy: 0.9835 - val_loss: 0.0427
# Epoch 44/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 301s 7s/step - accuracy: 0.9814 - loss: 0.0518 - val_accuracy: 0.9912 - val_loss: 0.0259
# Epoch 45/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 292s 7s/step - accuracy: 0.9811 - loss: 0.0441 - val_accuracy: 0.9852 - val_loss: 0.0371
# Epoch 46/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 294s 7s/step - accuracy: 0.9809 - loss: 0.0503 - val_accuracy: 0.9841 - val_loss: 0.0440
# Epoch 47/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 394s 10s/step - accuracy: 0.9785 - loss: 0.0610 - val_accuracy: 0.9831 - val_loss: 0.0448
# Epoch 48/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 303s 7s/step - accuracy: 0.9803 - loss: 0.0569 - val_accuracy: 0.9753 - val_loss: 0.0585
# Epoch 49/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 281s 7s/step - accuracy: 0.9807 - loss: 0.0488 - val_accuracy: 0.9651 - val_loss: 0.0897
# Epoch 50/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 295s 7s/step - accuracy: 0.9787 - loss: 0.0562 - val_accuracy: 0.9674 - val_loss: 0.0797

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# %% [markdown]
# ## LOSS V/S NUMBER OF EPOCHS

# %%
plt.figure(figsize=(15, 10))
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['Training loss','Validation loss'], fontsize=16)
plt.title("Loss Vs Epochs", fontsize=18)
plt.xlabel("Num. of Epochs", fontsize=16)
plt.ylabel("Loss", fontsize=16)
print("Loss Vs Num. of Epochs")
print("Training Loss : 0.0519","\nValue loss : 0.0701")
plt.show()
# Out:
# Loss Vs Num. of Epochs
# Training Loss : 0.0519
# Value loss : 0.0701

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %% [markdown]
# ## PLOTING ACCURACY V/S NUMBER OF EPCOHS

# %%
plt.figure(figsize=(15, 10))
plt.plot(acc)
plt.plot(val_acc)
plt.legend(['Training accuracy','Validation accuracy'], fontsize=16)
plt.title("Accuracy Vs Epochs", fontsize=18)
plt.xlabel("Num. of Epochs", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
print("Accuracy Vs Epochs")
print("Training accuracy : 0.9816","\nValue accuracy : 1.0000")
plt.show()
# Out:
# Accuracy Vs Epochs
# Training accuracy : 0.9816
# Value accuracy : 1.0000

# %%
cccc

# %%
import warnings
warnings.filterwarnings("ignore", message="Skipping variable loading for optimizer")

# %%
from keras.models import load_model
model = load_model("my_model.keras")

# %%
eval_datagen = ImageDataGenerator(rescale = 1/255)

test_generator = eval_datagen.flow_from_directory(
     r"C:\Users\pnuka\Desktop\LUNGS DEMO\chest_xray\test",
    target_size = (300, 300),
    batch_size = 128, 
    class_mode = 'binary'
)

eval_result = model.evaluate(test_generator, steps=624)

print('loss :', eval_result[0])
print('accuracy :', eval_result[1])
# Out:
# Found 624 images belonging to 2 classes.
# C:\Users\pnuka\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 624/624 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9247 - loss: 0.2143
# loss : 0.21443070471286774
# accuracy : 0.9246794581413269
# C:\Users\pnuka\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %%
img= cv2.imread()
tempimg = img
img = cv2.resize(img,(300,300))
img = img/255.0
img = img.reshape(1,300,300,3)
model.predict(img)

# %%
prediction = model.predict(img) >= 0.5
if prediction>=0.5:
  prediction = "Pneumonia"
else:
  prediction = "Normal"
plt.imshow(tempimg)
print("Prediction: "+prediction)
plt.title("Prediction: "+prediction, fontsize=14)

# %%
img= cv2.imread('/content/drive/MyDrive/chest_xray/test/PNEUMONIA/person104_bacteria_492.jpeg')
tempimg = img
img = cv2.resize(img,(300,300))
img = img/255.0
img = img.reshape(1,300,300,3)
model.predict(img)

# %%
prediction = model.predict(img) >= 0.5
if prediction>=0.5:
  prediction = "Pneumonia"
else:
  prediction = "Normal"
print("Prediction: "+prediction)
plt.imshow(tempimg)
plt.title("Prediction: "+prediction, fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 prediction = model.predict(img) >= 0.5
#       2 if prediction>=0.5:
#       3   prediction = "Pneumonia"
#
# NameError: name 'img' is not defined
